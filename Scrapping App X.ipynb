# %% [markdown]
# # Scrapping Dataset X.com (Twitter)
# * Nama : Andi Engku Putribuana
# * email : andiengku1922@gmail.com
# * id dicoding : putribuana

# %% [markdown]
# # Import Library

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.7 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.twitter.android',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=10000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_app.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %% [markdown]
# # Loading Dataset

# %%
import pandas as pd
ulasan_x = pd.DataFrame(scrapreview)
ulasan_x.shape
ulasan_x.head()
ulasan_x.to_csv('ulasan_x.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
ulasan_x = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = ulasan_x.shape

# Menampilkan hasil
print(f"Jumlah ulasan: {jumlah_ulasan}")
print(f"Jumlah kolom: {jumlah_kolom}")
# Out:
# Jumlah ulasan: 18000
# Jumlah kolom: 11

# %%
ulasan_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              18000 non-null  object
#  1   userName              18000 non-null  object
#  2   userImage             18000 non-null  object
#  3   content               18000 non-null  object
#  4   score                 18000 non-null  int64
#  5   thumbsUpCount         18000 non-null  int64
#  6   reviewCreatedVersion  13190 non-null  object
#  7   at                    18000 non-null  datetime64[ns]
#  8   replyContent          0 non-null      object
#  9   repliedAt             0 non-null      object
#  10  appVersion            13190 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 1.5+ MB

# %%
ulasan_x.describe(include='all')
# Out:
#                                     reviewId         userName  \
# count                                  18000            18000
# unique                                 18000                1
# top     cc7b2753-0c9b-43bd-98bd-4c55edb98d06  Pengguna Google
# freq                                       1            18000
# mean                                     NaN              NaN
# min                                      NaN              NaN
# 25%                                      NaN              NaN
# 50%                                      NaN              NaN
# 75%                                      NaN              NaN
# max                                      NaN              NaN
# std                                      NaN              NaN
#
#                                                 userImage           content  \
# count                                               18000             18000
# ...
